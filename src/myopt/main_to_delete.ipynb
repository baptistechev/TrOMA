# %%
import numpy as np
import data_structure as ds

# %%
dit_str = ds.integer_to_dit_string(125,3,10)
pat = ds.dit_string_to_computational_basis(dit_str, 3)
dev_pat = ds.kronecker_develop(pat, dit_dimension=3)
np.where(dev_pat==1)
# Out:
# (array([125]),)
